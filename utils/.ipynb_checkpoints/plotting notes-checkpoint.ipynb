# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# If you forget to create a figure at the beginning.
plt.plot([1,2,3],[1,2,3])
fig = plt.figure(1)
ax = fig._get_axes()
ax[0].set_xlabel('iteration')
ax[0].set_ylabel('rewards')
plt.show()
# plt.show()
# np.shape(ax)
